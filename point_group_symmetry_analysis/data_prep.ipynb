# %%
pip install numpy
pip install h5py
pip install rdkit
pip install py3Dmol
# Out:
# Collecting h5py
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.19.3 in ./venv/lib/python3.12/site-packages (from h5py) (2.3.2)
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 8.7 MB/s  0:00:00m eta 0:00:01
# Installing collected packages: h5py
# Successfully installed h5py-3.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import h5py
import time
import numpy as np
import json
import pymsym
import ira_mod
sofi = ira_mod.SOFI()

def save_data_hdf5(filename, all_atom_types, all_coords, all_smiles, all_selfies):
    """
    Save data using HDF5 - excellent for very large datasets
    """
    print(f"Starting to save {len(all_atom_types)} molecules to {filename}...")
    start_time = time.time()
    
    with h5py.File(filename, 'w') as f:
        # Save coordinates as variable-length arrays
        print("Saving coordinates...")
        coord_dt = h5py.special_dtype(vlen=np.dtype('float32'))
        coord_dset = f.create_dataset('coords', (len(all_coords),), dtype=coord_dt, 
                                     compression='gzip', compression_opts=9)
        
        for i, coords in enumerate(all_coords):
            if i % 10000 == 0:  # Progress indicator
                print(f"  Processed {i}/{len(all_coords)} coordinates...")
            coord_dset[i] = np.array(coords, dtype=np.float32).flatten()
        
        # Save atom types as variable-length strings
        print("Saving atom types...")
        atom_dt = h5py.special_dtype(vlen=str)
        atom_dset = f.create_dataset('atom_types', (len(all_atom_types),), dtype=atom_dt,
                                   compression='gzip', compression_opts=9)
        
        for i, atoms in enumerate(all_atom_types):
            if i % 10000 == 0:
                print(f"  Processed {i}/{len(all_atom_types)} atom types...")
            atom_dset[i] = '|'.join(atoms)  # Join with delimiter
        
        # Save SMILES and SELFIES
        print("Saving SMILES...")
        smiles_dset = f.create_dataset('smiles', (len(all_smiles),), dtype=atom_dt,
                                     compression='gzip', compression_opts=9)
        
        print("Saving SELFIES...")
        selfies_dset = f.create_dataset('selfies', (len(all_selfies),), dtype=atom_dt,
                                      compression='gzip', compression_opts=9)
        
        for i in range(len(all_smiles)):
            if i % 10000 == 0:
                print(f"  Processed {i}/{len(all_smiles)} strings...")
            smiles_dset[i] = all_smiles[i] if all_smiles[i] is not None else ""
            selfies_dset[i] = all_selfies[i] if all_selfies[i] is not None else ""
    
    end_time = time.time()
    print(f"Successfully saved to {filename} in {end_time - start_time:.2f} seconds")

def load_molecule_hdf5(filename, idx):
    """Load single molecule from HDF5 file"""
    with h5py.File(filename, 'r') as f:
        # Get coordinates and reshape
        coords_flat = f['coords'][idx]
        coords = coords_flat.reshape(-1, 3)
        
        # Get atom types (decode bytes to string)
        atom_types_str = f['atom_types'][idx]
        if isinstance(atom_types_str, bytes):
            atom_types_str = atom_types_str.decode('utf-8')
        atom_types = atom_types_str.split('|')
        
        # Get strings (decode bytes to string if necessary)
        smiles = f['smiles'][idx]
        if isinstance(smiles, bytes):
            smiles = smiles.decode('utf-8')
            
        selfies = f['selfies'][idx]
        if isinstance(selfies, bytes):
            selfies = selfies.decode('utf-8')
        
        return {
            'atom_types': atom_types,
            'coords': coords,
            'smiles': smiles,
            'selfies': selfies
        }

def get_dataset_info_hdf5(filename):
    """Get information about the HDF5 dataset"""
    with h5py.File(filename, 'r') as f:
        n_molecules = len(f['coords'])
        print(f"Dataset contains {n_molecules} molecules")
        
        # Sample first molecule for info
        sample_coords = f['coords'][69]
        
        sample_atoms_str = f['atom_types'][69]
        if isinstance(sample_atoms_str, bytes):
            sample_atoms_str = sample_atoms_str.decode('utf-8')
        sample_atoms = sample_atoms_str.split('|')
        
        sample_smiles = f['smiles'][69]
        if isinstance(sample_smiles, bytes):
            sample_smiles = sample_smiles.decode('utf-8')
        
        print(f"Sample molecule 69:")
        print(f"  Atoms: {sample_atoms}")
        print(f"  Coordinates shape: {sample_coords.reshape(-1, 3).shape}")
        print(f"  SMILES: {sample_smiles}")
        
        return n_molecules

# %%
print("Loading original data...")
data = np.load("mol3d_data/molecules_last_.9_million.npz", mmap_mode='r', allow_pickle=True)

# Convert to HDF5
print("Converting to HDF5...")
save_data_hdf5("mol3d_data/molecules3d_million4.h5", 
               data["atom_types"], data["coords"], 
               data["smiles"], data["selfies"])

# Test the converted data
print("\nTesting converted data...")
get_dataset_info_hdf5("mol3d_data/molecules3d_million4.h5")

print("\nConversion complete! You can now use 'molecules_1st_million.h5' for fast access.")
# Out:
# Loading original data...
# Converting to HDF5...
# Starting to save 899644 molecules to mol3d_data/molecules3d_million4.h5...
# Saving coordinates...
#   Processed 0/899644 coordinates...
#   Processed 10000/899644 coordinates...
#   Processed 20000/899644 coordinates...
#   Processed 30000/899644 coordinates...
#   Processed 40000/899644 coordinates...
#   Processed 50000/899644 coordinates...
#   Processed 60000/899644 coordinates...
#   Processed 70000/899644 coordinates...
#   Processed 80000/899644 coordinates...
#   Processed 90000/899644 coordinates...
#   Processed 100000/899644 coordinates...
#   Processed 110000/899644 coordinates...
#   Processed 120000/899644 coordinates...
#   Processed 130000/899644 coordinates...
#   Processed 140000/899644 coordinates...
#   Processed 150000/899644 coordinates...
#   Processed 160000/899644 coordinates...
#   Processed 170000/899644 coordinates...
#   Processed 180000/899644 coordinates...
#   Processed 190000/899644 coordinates...
#   Processed 200000/899644 coordinates...
#   Processed 210000/899644 coordinates...
#   Processed 220000/899644 coordinates...
#   Processed 230000/899644 coordinates...
#   Processed 240000/899644 coordinates...
#   Processed 250000/899644 coordinates...
#   Processed 260000/899644 coordinates...
#   Processed 270000/899644 coordinates...
#   Processed 280000/899644 coordinates...
#   Processed 290000/899644 coordinates...
#   Processed 300000/899644 coordinates...
#   Processed 310000/899644 coordinates...
#   Processed 320000/899644 coordinates...
#   Processed 330000/899644 coordinates...
#   Processed 340000/899644 coordinates...
#   Processed 350000/899644 coordinates...
#   Processed 360000/899644 coordinates...
#   Processed 370000/899644 coordinates...
#   Processed 380000/899644 coordinates...
#   Processed 390000/899644 coordinates...
#   Processed 400000/899644 coordinates...
#   Processed 410000/899644 coordinates...
#   Processed 420000/899644 coordinates...
#   Processed 430000/899644 coordinates...
#   Processed 440000/899644 coordinates...
#   Processed 450000/899644 coordinates...
#   Processed 460000/899644 coordinates...
#   Processed 470000/899644 coordinates...
#   Processed 480000/899644 coordinates...
#   Processed 490000/899644 coordinates...
#   Processed 500000/899644 coordinates...
#   Processed 510000/899644 coordinates...
#   Processed 520000/899644 coordinates...
#   Processed 530000/899644 coordinates...
#   Processed 540000/899644 coordinates...
#   Processed 550000/899644 coordinates...
#   Processed 560000/899644 coordinates...
#   Processed 570000/899644 coordinates...
#   Processed 580000/899644 coordinates...
#   Processed 590000/899644 coordinates...
#   Processed 600000/899644 coordinates...
#   Processed 610000/899644 coordinates...
#   Processed 620000/899644 coordinates...
#   Processed 630000/899644 coordinates...
#   Processed 640000/899644 coordinates...
#   Processed 650000/899644 coordinates...
#   Processed 660000/899644 coordinates...
#   Processed 670000/899644 coordinates...
#   Processed 680000/899644 coordinates...
#   Processed 690000/899644 coordinates...
#   Processed 700000/899644 coordinates...
#   Processed 710000/899644 coordinates...
#   Processed 720000/899644 coordinates...
#   Processed 730000/899644 coordinates...
#   Processed 740000/899644 coordinates...
#   Processed 750000/899644 coordinates...
#   Processed 760000/899644 coordinates...
#   Processed 770000/899644 coordinates...
#   Processed 780000/899644 coordinates...
#   Processed 790000/899644 coordinates...
#   Processed 800000/899644 coordinates...
#   Processed 810000/899644 coordinates...
#   Processed 820000/899644 coordinates...
#   Processed 830000/899644 coordinates...
#   Processed 840000/899644 coordinates...
#   Processed 850000/899644 coordinates...
#   Processed 860000/899644 coordinates...
#   Processed 870000/899644 coordinates...
#   Processed 880000/899644 coordinates...
#   Processed 890000/899644 coordinates...
# Saving atom types...
#   Processed 0/899644 atom types...
#   Processed 10000/899644 atom types...
#   Processed 20000/899644 atom types...
#   Processed 30000/899644 atom types...
#   Processed 40000/899644 atom types...
#   Processed 50000/899644 atom types...
#   Processed 60000/899644 atom types...
#   Processed 70000/899644 atom types...
#   Processed 80000/899644 atom types...
#   Processed 90000/899644 atom types...
#   Processed 100000/899644 atom types...
#   Processed 110000/899644 atom types...
#   Processed 120000/899644 atom types...
#   Processed 130000/899644 atom types...
#   Processed 140000/899644 atom types...
#   Processed 150000/899644 atom types...
#   Processed 160000/899644 atom types...
#   Processed 170000/899644 atom types...
#   Processed 180000/899644 atom types...
#   Processed 190000/899644 atom types...
#   Processed 200000/899644 atom types...
#   Processed 210000/899644 atom types...
#   Processed 220000/899644 atom types...
#   Processed 230000/899644 atom types...
#   Processed 240000/899644 atom types...
#   Processed 250000/899644 atom types...
#   Processed 260000/899644 atom types...
#   Processed 270000/899644 atom types...
#   Processed 280000/899644 atom types...
#   Processed 290000/899644 atom types...
#   Processed 300000/899644 atom types...
#   Processed 310000/899644 atom types...
#   Processed 320000/899644 atom types...
#   Processed 330000/899644 atom types...
#   Processed 340000/899644 atom types...
#   Processed 350000/899644 atom types...
#   Processed 360000/899644 atom types...
#   Processed 370000/899644 atom types...
#   Processed 380000/899644 atom types...
#   Processed 390000/899644 atom types...
#   Processed 400000/899644 atom types...
#   Processed 410000/899644 atom types...
#   Processed 420000/899644 atom types...
#   Processed 430000/899644 atom types...
#   Processed 440000/899644 atom types...
#   Processed 450000/899644 atom types...
#   Processed 460000/899644 atom types...
#   Processed 470000/899644 atom types...
#   Processed 480000/899644 atom types...
#   Processed 490000/899644 atom types...
#   Processed 500000/899644 atom types...
#   Processed 510000/899644 atom types...
#   Processed 520000/899644 atom types...
#   Processed 530000/899644 atom types...
#   Processed 540000/899644 atom types...
#   Processed 550000/899644 atom types...
#   Processed 560000/899644 atom types...
#   Processed 570000/899644 atom types...
#   Processed 580000/899644 atom types...
#   Processed 590000/899644 atom types...
#   Processed 600000/899644 atom types...
#   Processed 610000/899644 atom types...
#   Processed 620000/899644 atom types...
#   Processed 630000/899644 atom types...
#   Processed 640000/899644 atom types...
#   Processed 650000/899644 atom types...
#   Processed 660000/899644 atom types...
#   Processed 670000/899644 atom types...
#   Processed 680000/899644 atom types...
#   Processed 690000/899644 atom types...
#   Processed 700000/899644 atom types...
#   Processed 710000/899644 atom types...
#   Processed 720000/899644 atom types...
#   Processed 730000/899644 atom types...
#   Processed 740000/899644 atom types...
#   Processed 750000/899644 atom types...
#   Processed 760000/899644 atom types...
#   Processed 770000/899644 atom types...
#   Processed 780000/899644 atom types...
#   Processed 790000/899644 atom types...
#   Processed 800000/899644 atom types...
#   Processed 810000/899644 atom types...
#   Processed 820000/899644 atom types...
#   Processed 830000/899644 atom types...
#   Processed 840000/899644 atom types...
#   Processed 850000/899644 atom types...
#   Processed 860000/899644 atom types...
#   Processed 870000/899644 atom types...
#   Processed 880000/899644 atom types...
#   Processed 890000/899644 atom types...
# Saving SMILES...
# Saving SELFIES...
#   Processed 0/899644 strings...
#   Processed 10000/899644 strings...
#   Processed 20000/899644 strings...
#   Processed 30000/899644 strings...
#   Processed 40000/899644 strings...
#   Processed 50000/899644 strings...
#   Processed 60000/899644 strings...
#   Processed 70000/899644 strings...
#   Processed 80000/899644 strings...
#   Processed 90000/899644 strings...
#   Processed 100000/899644 strings...
#   Processed 110000/899644 strings...
#   Processed 120000/899644 strings...
#   Processed 130000/899644 strings...
#   Processed 140000/899644 strings...
#   Processed 150000/899644 strings...
#   Processed 160000/899644 strings...
#   Processed 170000/899644 strings...
#   Processed 180000/899644 strings...
#   Processed 190000/899644 strings...
#   Processed 200000/899644 strings...
#   Processed 210000/899644 strings...
#   Processed 220000/899644 strings...
#   Processed 230000/899644 strings...
#   Processed 240000/899644 strings...
#   Processed 250000/899644 strings...
#   Processed 260000/899644 strings...
#   Processed 270000/899644 strings...
#   Processed 280000/899644 strings...
#   Processed 290000/899644 strings...
#   Processed 300000/899644 strings...
#   Processed 310000/899644 strings...
#   Processed 320000/899644 strings...
#   Processed 330000/899644 strings...
#   Processed 340000/899644 strings...
#   Processed 350000/899644 strings...
#   Processed 360000/899644 strings...
#   Processed 370000/899644 strings...
#   Processed 380000/899644 strings...
#   Processed 390000/899644 strings...
#   Processed 400000/899644 strings...
#   Processed 410000/899644 strings...
#   Processed 420000/899644 strings...
#   Processed 430000/899644 strings...
#   Processed 440000/899644 strings...
#   Processed 450000/899644 strings...
#   Processed 460000/899644 strings...
#   Processed 470000/899644 strings...
#   Processed 480000/899644 strings...
#   Processed 490000/899644 strings...
#   Processed 500000/899644 strings...
#   Processed 510000/899644 strings...
#   Processed 520000/899644 strings...
#   Processed 530000/899644 strings...
#   Processed 540000/899644 strings...
#   Processed 550000/899644 strings...
#   Processed 560000/899644 strings...
#   Processed 570000/899644 strings...
#   Processed 580000/899644 strings...
#   Processed 590000/899644 strings...
#   Processed 600000/899644 strings...
#   Processed 610000/899644 strings...
#   Processed 620000/899644 strings...
#   Processed 630000/899644 strings...
#   Processed 640000/899644 strings...
#   Processed 650000/899644 strings...
#   Processed 660000/899644 strings...
#   Processed 670000/899644 strings...
#   Processed 680000/899644 strings...
#   Processed 690000/899644 strings...
#   Processed 700000/899644 strings...
#   Processed 710000/899644 strings...
#   Processed 720000/899644 strings...
#   Processed 730000/899644 strings...
#   Processed 740000/899644 strings...
#   Processed 750000/899644 strings...
#   Processed 760000/899644 strings...
#   Processed 770000/899644 strings...
#   Processed 780000/899644 strings...
#   Processed 790000/899644 strings...
#   Processed 800000/899644 strings...
#   Processed 810000/899644 strings...
#   Processed 820000/899644 strings...
#   Processed 830000/899644 strings...
#   Processed 840000/899644 strings...
#   Processed 850000/899644 strings...
#   Processed 860000/899644 strings...
#   Processed 870000/899644 strings...
#   Processed 880000/899644 strings...
#   Processed 890000/899644 strings...
# Successfully saved to mol3d_data/molecules3d_million4.h5 in 313.32 seconds
#
# Testing converted data...
# Dataset contains 899644 molecules
# Sample molecule 0:
#   Atoms: ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'N', 'N', 'O', 'O', 'O', 'O', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
#   Coordinates shape: (31, 3)
#   SMILES: [H][N][C](O[H])[C@@]1([H])N(C(=O)C([H])([H])OC([H])([H])C([H])([H])[H])C([H])([H])[C@]([H])(O[H])C1([H])[H]
#
# Conversion complete! You can now use 'molecules_1st_million.h5' for fast access.

# %%
# Test access speed
print("\nTesting access speed...")
start = time.time()
for i in [42, 69, 271, 314, 1024]:
    mol = load_molecule_hdf5("mol3d_data/molecules_1st_million.h5", i)
    print(f"Molecule {i}: {len(mol['atom_types'])} atoms, SMILES: {mol['smiles'][:20]}...")
end = time.time()
print(f"Accessed 5 molecules in {end - start:.4f} seconds")
# Out:
# Testing access speed...
# Molecule 42: 12 atoms, SMILES: [H]OC(=O)C([H])(O[H]...
# Molecule 69: 20 atoms, SMILES: [H]OC(=O)C1=C([H])C(...
# Molecule 271: 26 atoms, SMILES: [H]O[C@]1([H])[C@@](...
# Molecule 314: 25 atoms, SMILES: [H]c1nc([H])c([C@]2(...
# Molecule 1024: 26 atoms, SMILES: [H]c1c([H])c(Cl)c([H...
# Accessed 5 molecules in 0.0488 seconds

# %%
n = 69
# Convert to required format
mol = load_molecule_hdf5("mol3d_data/molecules3d_million1.h5", problematic_mol_id) # problematic_mol_id <-> n
atoms = mol["atom_types"]
nat = len(atoms)  # Number of atoms
coords = np.array(mol["coords"], dtype=float)  # Coordinates as numpy array

print(f"Structure has {nat} atoms")
print(f"Atom types: {atoms}")

# Map atom types to integers
unique_atoms = list(set(atoms))
atom_type_map = {atom: i+1 for i, atom in enumerate(sorted(unique_atoms))}
print(f"Atom type mapping: {atom_type_map}")
typ = np.array([atom_type_map[atom] for atom in atoms], dtype=int)

# Set symmetry threshold - this determines how precisely atoms must match
# after applying symmetry operations (typical values: 0.01-0.1)
sym_thr = 0.1

sym = sofi.compute(nat, typ, coords, sym_thr)

# Print results
print(f"Symmetry threshold used: {sym_thr}")
print(f"Point Group: {sym.pg}")
print(f"Number of symmetry operations: {sym.n_sym}")
print(f"Number of principal axes: {sym.n_prin_ax}")
print(f"Principal axes:")
for i, axis in enumerate(sym.prin_ax):
    print(f"  Axis {i+1}: [{axis[0]:.6f}, {axis[1]:.6f}, {axis[2]:.6f}]")

print("\nSymmetry operations:")
for i in range(sym.n_sym):
    op, n, p, axis, angle = sofi.analmat(sym.matrix[i])
    print(f"  {i+1}: {op}{n}^{p}, axis=[{axis[0]:.3f}, {axis[1]:.3f}, {axis[2]:.3f}], angle={angle:.3f}")
    
print(f"Geometric center: {np.mean(coords, axis=0)}")
print(f"\nHausdorff distances: {sym.dHausdorff}")

# IMPORTANT: sofi.compute() does NOT automatically check for linearity!
# We need to do this manually and correct the point group if needed
is_collinear, linear_axis = sofi.check_collinear(nat, coords)
if is_collinear:
    print(f"\n*** LINEAR MOLECULE DETECTED ***")
    print(f"Structure is linear along axis: [{linear_axis[0]:.3f}, {linear_axis[1]:.3f}, {linear_axis[2]:.3f}]")
    
    # Correct the point group for linear molecules
    if sym.n_sym == 1:
        sym.pg = "C∞v"  # or "Cnv" as shown in documentation
        print("Corrected Point Group: C∞v (linear molecule without inversion)")
    else:
        sym.pg = "D∞h"  # or "Dnh" as shown in documentation  
        print("Corrected Point Group: D∞h (linear molecule with inversion)")
else:
    print(f"\nMolecule is not linear - point group {sym.pg} is correct")
# Out:
# Structure has 15 atoms
# Atom types: ['C', 'C', 'C', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H']
# Atom type mapping: {'C': 1, 'H': 2}
# Symmetry threshold used: 0.1
# Point Group: Cs
# Number of symmetry operations: 2
# Number of principal axes: 1
# Principal axes:
#   Axis 1: [0.327376, 0.944867, 0.007099]
#
# Symmetry operations:
#   1: E0^1, axis=[1.000, 0.000, 0.000], angle=0.000
#   2: S0^1, axis=[0.327, 0.945, 0.007], angle=0.000
# Geometric center: [0.00562002 0.00013999 0.00528   ]
#
# Hausdorff distances: [8.00593208e-16 2.93250366e-02]
#
# Molecule is not linear - point group Cs is correct

# %%
import random
random.seed(42)

dataloc = "mol3d_data/molecules3d_million1.h5"
with h5py.File(dataloc, 'r') as f:
    n_molecules = len(f['atom_types'])
    print(f"File has {n_molecules} entries")
          
n_samples = 100000
sample_ids = random.sample(range(0, n_molecules), n_samples)
# Out:
# File has 999993 entries

# %%
mil = 4
dataloc = f"mol3d_data/molecules3d_million_{mil}.h5"
with h5py.File(dataloc, 'r') as f:
    n_molecules = len(f['atom_types'])
    sample_ids = list(range(n_molecules))
    print(f"File has {n_molecules} entries")
n_samples = n_molecules
# Out:
# File has 899644 entries

# %%
max_sym_thr = 1.4
min_sym_thr = 0.4
sym_thr = 0.4
point_groups = []
failed_ids = []

for si in sample_ids:
    
    if (si+1) % 10000 == 0:
        print(f"Processing molecule {si+1}/{n_molecules}")
    
    try:
        mol = load_molecule_hdf5(dataloc, si)
        atoms = mol["atom_types"]
        nat = len(atoms)  # Number of atoms
        coords = np.array(mol["coords"], dtype=float)  # Coordinates as numpy array

        #sym_thr = max_sym_thr - (max_sym_thr - min_sym_thr) * np.exp(-(nat - 2) / 30)
        
        # Map atom types to integers
        unique_atoms = list(set(atoms))
        atom_type_map = {atom: i+1 for i, atom in enumerate(sorted(unique_atoms))}
        typ = np.array([atom_type_map[atom] for atom in atoms], dtype=int)
        
        sym = sofi.compute(nat, typ, coords, sym_thr)
        
        is_collinear, linear_axis = sofi.check_collinear(nat, coords)
        if is_collinear:
            # Correct the point group for linear molecules
            if sym.n_sym == 1:
                sym.pg = "C∞v"  # or "Cnv" as shown in documentation
            else:
                sym.pg = "D∞h"  # or "Dnh" as shown in documentation  
        
        point_groups.append(sym.pg)
        
    except Exception as e:
        # Catch the error and log the molecule ID
        failed_ids.append(si)
        point_groups.append('failed')
        print(f"Molecule {si} failed: {e}")
        continue  # skip to next molecule
# Out:
# Processing molecule 10000/899644
# Processing molecule 20000/899644
# Processing molecule 30000/899644
# Processing molecule 40000/899644
# Processing molecule 50000/899644
# Processing molecule 60000/899644
# Processing molecule 70000/899644
# Processing molecule 80000/899644
# Processing molecule 90000/899644
# Processing molecule 100000/899644
# Processing molecule 110000/899644
# Processing molecule 120000/899644
# Processing molecule 130000/899644
# Processing molecule 140000/899644
# Processing molecule 150000/899644
# Processing molecule 160000/899644
# Processing molecule 170000/899644
# Processing molecule 180000/899644
# Processing molecule 190000/899644
# Processing molecule 200000/899644
# Processing molecule 210000/899644
# Processing molecule 220000/899644
# Processing molecule 230000/899644
# Processing molecule 240000/899644
# Processing molecule 250000/899644
# Processing molecule 260000/899644
# Processing molecule 270000/899644
# Processing molecule 280000/899644
# Processing molecule 290000/899644
# Processing molecule 300000/899644
# Processing molecule 310000/899644
# Processing molecule 320000/899644
# Processing molecule 330000/899644
# Processing molecule 340000/899644
# Processing molecule 350000/899644
# Processing molecule 360000/899644
# Processing molecule 370000/899644
# Processing molecule 380000/899644
# Processing molecule 390000/899644
# Processing molecule 400000/899644
# Processing molecule 410000/899644
# Processing molecule 420000/899644
# Processing molecule 430000/899644
# Processing molecule 440000/899644
# Processing molecule 450000/899644
# Processing molecule 460000/899644
# Processing molecule 470000/899644
# Processing molecule 480000/899644
# Processing molecule 490000/899644
# Processing molecule 500000/899644
# Processing molecule 510000/899644
# Processing molecule 520000/899644
# Processing molecule 530000/899644
# Processing molecule 540000/899644
# Processing molecule 550000/899644
# Processing molecule 560000/899644
# Processing molecule 570000/899644
# Processing molecule 580000/899644
# Processing molecule 590000/899644
# Processing molecule 600000/899644
# Processing molecule 610000/899644
# Processing molecule 620000/899644
# Processing molecule 630000/899644
# Processing molecule 640000/899644
# Processing molecule 650000/899644
# Processing molecule 660000/899644
# Processing molecule 670000/899644
# Processing molecule 680000/899644
# Processing molecule 690000/899644
# Processing molecule 700000/899644
# Processing molecule 710000/899644
# Molecule 717065 failed: nonzero error value obtained from libira_compute_all()
#  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  ERROR: cannot set beta. Structure not properly shifted?
#  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  small norm:  0.40000000000000002
#            4
#  i=           1 j=           5
#            4  0.37399999797344208      -0.17877499014139175      -0.27667498216032982
#            2 -0.92270000278949738       0.30412500351667404       0.47152503207325935
#            1  -1.1180999428033829       0.84122499078512192        1.3030249662697315
#            3   1.6667999476194382      -0.96657500416040421       -1.4978750161826611
#  origin at: /home/turih/IterativeRotationsAssignments/src/sofi_routines.f90 line:         454
#  at: /home/turih/IterativeRotationsAssignments/src/sofi_routines.f90 line:         100
#       ERROR FROM IRA/SOFI library ::: Cannot set beta basis!
# Processing molecule 720000/899644
# Processing molecule 730000/899644
# Processing molecule 740000/899644
# Molecule 740730 failed: nonzero error value obtained from libira_compute_all()
#  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  ERROR: cannot set beta. Structure not properly shifted?
#  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  small norm:  0.40000000000000002
#           10
#  i=           1 j=          11
#            1  0.62321985363960231        3.3999942243099213E-003   1.3629999943077564E-002
#            1 -0.66588007807731664       -1.4800000935792923E-002  -9.8700011149048805E-003
#            1   1.8945201694965359        8.9999996125698090E-003   4.7030000947415829E-002
#            1  -1.9386800467967991       -3.3500004559755325E-002  -3.4669996239244938E-002
#            1   3.2108200848102566        2.2999979555606842E-003   8.9530001394450665E-002
#            1  -3.2557800352573398       -5.4600004106760025E-002  -6.0070001520216465E-002
#            3  -3.8284800291061405       0.74699997529387474      -0.52186997327953577
#            3   3.8214200794696804      -0.77569997683167458       0.53852997627109289
#            3  -3.8194800257682804      -0.87610000744462013       0.37712998595088720
#            2   3.9583200275897976       0.99300002679228783      -0.43936999235302210
#  origin at: /home/turih/IterativeRotationsAssignments/src/sofi_routines.f90 line:         454
#  at: /home/turih/IterativeRotationsAssignments/src/sofi_routines.f90 line:         100
#       ERROR FROM IRA/SOFI library ::: Cannot set beta basis!
# Processing molecule 750000/899644
# Processing molecule 760000/899644
# Processing molecule 770000/899644
# Processing molecule 780000/899644
# Processing molecule 790000/899644
# Processing molecule 800000/899644
# Processing molecule 810000/899644
# Processing molecule 820000/899644
# Processing molecule 830000/899644
# Processing molecule 840000/899644
# Processing molecule 850000/899644
# Processing molecule 860000/899644
# Processing molecule 870000/899644
# Processing molecule 880000/899644
# Processing molecule 890000/899644

# %%
sym_thr = 0.3
perturbation_scale = 1e-1
point_groups_with_some_noise = []
np.random.seed(43)  # for reproducibility

for fi in failed_ids:

    try:
        mol = load_molecule_hdf5(dataloc, fi)
        atoms = mol["atom_types"]
        nat = len(atoms)  # Number of atoms
        coords = np.array(mol["coords"], dtype=float)  # Coordinates as numpy array
        
        # Perturb linear fragments slightly by adding a very small 
        # random perpendicular displacement to the straight C atoms spine

        c_mask = np.array([a == 'C' for a in atoms])
        n_c = np.sum(c_mask)
        
        is_collinear, linear_axis = sofi.check_collinear(n_c, coords[:n_c])
        
        if abs(linear_axis[0]) < 0.9:
            helper = np.array([1.0, 0.0, 0.0])
        else:
            helper = np.array([0.0, 1.0, 0.0])

        # first perpendicular vector
        perp1 = np.cross(linear_axis, helper)
        perp1 /= np.linalg.norm(perp1)
        # second perpendicular vector
        perp2 = np.cross(linear_axis, perp1)
        perp2 /= np.linalg.norm(perp2)

        perturbation = np.zeros_like(coords)
        random_offsets = (np.random.randn(n_c, 1) * perp1 + np.random.randn(n_c, 1) * perp2)[:, :3]
        perturbation[:n_c] = random_offsets * perturbation_scale
        
        coords += perturbation
        
        # Map atom types to integers
        unique_atoms = list(set(atoms))
        atom_type_map = {atom: i+1 for i, atom in enumerate(sorted(unique_atoms))}
        typ = np.array([atom_type_map[atom] for atom in atoms], dtype=int)
        
        sym = sofi.compute(nat, typ, coords, sym_thr)

        is_collinear, linear_axis = sofi.check_collinear(nat, coords)
        if is_collinear:
            # Correct the point group for linear molecules
            if sym.n_sym == 1:
                sym.pg = "C∞v"  # or "Cnv" as shown in documentation
            else:
                sym.pg = "D∞h"  # or "Dnh" as shown in documentation  
        print(sym.pg)
        point_groups_with_some_noise.append(sym.pg)
    except:
        pass
print(point_groups_with_some_noise)
# Out:
# D3h
# D2d
# C1
# C2
#  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  ERROR: cannot set beta. Structure not properly shifted?
#  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  small norm:  0.29999999999999999
#            6
#  i=           1 j=           7
#            1  0.53950993681103787       0.12969781315053980        3.7446830511381896E-003
#            1 -0.74388121194645507        1.4829980199682222E-002  -6.1859465610855223E-002
#            1   1.8117913204516458       0.13157408674044763      -0.24495649341547637
#            3  -1.9533733785748513        9.3032713874434125E-002  -9.8376234475643851E-002
#            2  -2.6444733799099951      -0.40926730457022320       0.44282374629366256
#            4   2.9904267131686182        4.0132710605119359E-002  -4.1376235842825390E-002
#  origin at: /home/turih/IterativeRotationsAssignments/src/sofi_routines.f90 line:         454
#  at: /home/turih/IterativeRotationsAssignments/src/sofi_routines.f90 line:         100
#       ERROR FROM IRA/SOFI library ::: Cannot set beta basis!
#  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  ERROR: cannot set beta. Structure not properly shifted?
#  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#  small norm:  0.29999999999999999
#           10
#  i=           1 j=          11
#            1 -0.67819963229761338       -2.9005664551616864E-004   3.7012639263693456E-002
#            1  0.67876555018718809       -9.6057385884414662E-002   1.1694419109649506E-002
#            1   1.8989501453913389      -0.12685459034633434       -8.6549410645434088E-002
#            1  -1.9002852063944828       0.18089168381470105       -6.9965461911810745E-002
#            1  -3.3445922690570993        8.2261605569657226E-002   5.4590537569813767E-002
#            1   3.3449282959322084      -0.14510742796618178       -2.2844468054933273E-002
#            2   3.8074832332832482       0.29408904987998891       0.96444044738484946
#            2  -3.8066167461173865       0.99748903590866012      -0.19585956901834878
#            3  -4.0119166003959510      -0.96301096599868852       0.29744042187406150
#            3   4.0114832294685510      -0.22341094833187175      -0.98995955557154092
#  origin at: /home/turih/IterativeRotationsAssignments/src/sofi_routines.f90 line:         454
#  at: /home/turih/IterativeRotationsAssignments/src/sofi_routines.f90 line:         100
#       ERROR FROM IRA/SOFI library ::: Cannot set beta basis!
# C1
# C2h
# C1
# ['D3h', 'D2d', 'C1', 'C2', 'C1', 'C2h', 'C1']

# %%
with open(f"point_groups_million_{mil}_sym_thr_0.4_sofi.json", "w") as f:
    json.dump(point_groups, f)

# %%
with open(f"failed_ids_million_{mil}_sym_thr_0.4_sofi.json", "w") as f:
    json.dump(failed_ids, f)

# %%
point_groups = []
failed_ids = []

# Convert atom symbols to atomic numbers
# pymsym requires atomic numbers, not symbols
periodic_table = {
    'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8,
    'F': 9, 'Ne': 10, 'Na': 11, 'Mg': 12, 'Al': 13, 'Si': 14, 'P': 15,
    'S': 16, 'Cl': 17, 'Ar': 18, 'K': 19, 'Ca': 20, 'Sc': 21, 'Ti': 22,
    'V': 23, 'Cr': 24, 'Mn': 25, 'Fe': 26, 'Co': 27, 'Ni': 28, 'Cu': 29,
    'Zn': 30, 'Ga': 31, 'Ge': 32, 'As': 33, 'Se': 34, 'Br': 35, 'Kr': 36,
    'Rb': 37, 'Sr': 38, 'Y': 39, 'Zr': 40, 'Nb': 41, 'Mo': 42, 'Tc': 43,
    'Ru': 44, 'Rh': 45, 'Pd': 46, 'Ag': 47, 'Cd': 48, 'In': 49, 'Sn': 50
}

for si in sample_ids:

    if (si+1) % 10000 == 0:
        print(f"Processing molecule {si+1}/{n_molecules}")
    
    mol = load_molecule_hdf5(dataloc, si)
    atoms = mol["atom_types"]
    coords = np.array(mol["coords"], dtype=float)  # Coordinates as numpy array
    
    atomic_numbers = [periodic_table[a] for a in atoms]

    # Find the point group
    try:
        point_groups.append(pymsym.get_point_group(atomic_numbers, coords))
    except Exception as e:
        failed_ids.append(si)
        point_groups.append("failed")
        print(f"Error determining point group: {e}")
        
point_groups = [pg.replace("Cinfv", "C∞v").replace("Dinfh", "D∞h") for pg in point_groups]
# Out:
# Processing molecule 10000/899644
# Processing molecule 20000/899644
# Processing molecule 30000/899644
# Processing molecule 40000/899644
# Processing molecule 50000/899644
# Processing molecule 60000/899644
# Processing molecule 70000/899644
# Processing molecule 80000/899644
# Processing molecule 90000/899644
# Processing molecule 100000/899644
# Processing molecule 110000/899644
# Processing molecule 120000/899644
# Processing molecule 130000/899644
# Processing molecule 140000/899644
# Processing molecule 150000/899644
# Processing molecule 160000/899644
# Processing molecule 170000/899644
# Processing molecule 180000/899644
# Processing molecule 190000/899644
# Processing molecule 200000/899644
# Processing molecule 210000/899644
# Processing molecule 220000/899644
# Processing molecule 230000/899644
# Processing molecule 240000/899644
# Processing molecule 250000/899644
# Processing molecule 260000/899644
# Processing molecule 270000/899644
# Processing molecule 280000/899644
# Processing molecule 290000/899644
# Processing molecule 300000/899644
# Processing molecule 310000/899644
# Processing molecule 320000/899644
# Processing molecule 330000/899644
# Processing molecule 340000/899644
# Processing molecule 350000/899644
# Processing molecule 360000/899644
# Processing molecule 370000/899644
# Processing molecule 380000/899644
# Processing molecule 390000/899644
# Processing molecule 400000/899644
# Processing molecule 410000/899644
# Processing molecule 420000/899644
# Processing molecule 430000/899644
# Processing molecule 440000/899644
# Processing molecule 450000/899644
# Processing molecule 460000/899644
# Processing molecule 470000/899644
# Processing molecule 480000/899644
# Processing molecule 490000/899644
# Processing molecule 500000/899644
# Processing molecule 510000/899644
# Processing molecule 520000/899644
# Processing molecule 530000/899644
# Processing molecule 540000/899644
# Processing molecule 550000/899644
# Processing molecule 560000/899644
# Processing molecule 570000/899644
# Processing molecule 580000/899644
# Processing molecule 590000/899644
# Processing molecule 600000/899644
# Processing molecule 610000/899644
# Processing molecule 620000/899644
# Processing molecule 630000/899644
# Processing molecule 640000/899644
# Processing molecule 650000/899644
# Processing molecule 660000/899644
# Processing molecule 670000/899644
# Processing molecule 680000/899644
# Processing molecule 690000/899644
# Processing molecule 700000/899644
# Processing molecule 710000/899644
# Processing molecule 720000/899644
# Processing molecule 730000/899644
# Processing molecule 740000/899644
# Processing molecule 750000/899644
# Processing molecule 760000/899644
# Processing molecule 770000/899644
# Processing molecule 780000/899644
# Processing molecule 790000/899644
# Processing molecule 800000/899644
# Processing molecule 810000/899644
# Processing molecule 820000/899644
# Processing molecule 830000/899644
# Processing molecule 840000/899644
# Processing molecule 850000/899644
# Processing molecule 860000/899644
# Processing molecule 870000/899644
# Processing molecule 880000/899644
# Processing molecule 890000/899644

# %%
with open(f"point_groups_million_{mil}_pymsym.json", "w") as f:
    json.dump(point_groups, f)
