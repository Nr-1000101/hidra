# %%
import os
import numpy as np
from rdkit import Chem
import selfies as sf
import h5py
import json
import re

def process_data(sdf_file):
    """Loads and converts/computes all the relevant data"""
    supplier = Chem.SDMolSupplier(sdf_file, sanitize=True, removeHs=False)
    all_atoms, all_coords, all_smiles, all_selfies, all_ring_counts, all_rings = [], [], [], [], [], []
    isomers = {}  # <--- track duplicates

    for i, mol in enumerate(supplier):
        l = len(all_smiles)
        if mol is None:
            # print(f"[{i}] molecule failed to load") # i <-> l
            # all_atoms.append(None)
            # all_coords.append(None)
            # all_smiles.append(None)
            continue
        
        # Get atom types
        atoms = [atom.GetSymbol() for atom in mol.GetAtoms()]
        if len(atoms) < 2:
            # print(f"{i} molecule is a single atom") # i <-> l
            # all_atoms.append(None)
            # all_coords.append(None)
            # all_smiles.append(None)
            continue
        
        # Get ring information
        ring_info = mol.GetRingInfo()
        # Get list of rings (each ring is a tuple of atom indices)
        rings = ring_info.AtomRings()
        ring_count = len(rings)
        
        # Check fragmentation
        fragments = Chem.GetMolFrags(mol)
        if len(fragments) > 1:
            # print(f"{i} molecule is supposedly fragmented") # i <-> l
            # frag = is_physically_fragmented(mol)
            # if frag == True:
                # print(f"{i} molecule is geometrically fragmented too") # i <-> l
                # all_atoms.append(None)
                # all_coords.append(None)
                # all_smiles.append(None)
            continue
        
        # Coordinates
        coords = [mol.GetConformer().GetAtomPosition(j) for j in range(mol.GetNumAtoms())]
        coords = np.array([[c.x, c.y, c.z] for c in coords], dtype=np.float32)

        # 2-atom molecule too far apart
        if len(atoms) == 2:
            dist = np.linalg.norm(coords[0] - coords[1])
            if dist > 3:
                # print(f"{i} molecule is comprised of 2 non-interacting atoms (dist={dist:.2f})") # i <-> l
                # all_atoms.append(None)
                # all_coords.append(None)
                # all_smiles.append(None)
                continue
                
        # Remove explicit hydrogens
        mol_no_H = Chem.RemoveHs(mol, implicitOnly=False, updateExplicitCount=True, sanitize=True)
        Chem.SanitizeMol(mol_no_H, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL)
        
        # SMILES (canonicalized)
        try:            
            Chem.AssignStereochemistry(mol_no_H, cleanIt=True, force=True)
            smiles = Chem.MolToSmiles(mol_no_H, kekuleSmiles=True, canonical=True, isomericSmiles=True, allHsExplicit=False)
        except:
            # print(f"{i} SMILES failed to generate")
            # all_atoms.append(None)
            # all_coords.append(None)
            # all_smiles.append(None)
            continue
            
        try:
            smiles_no_stereo = Chem.MolToSmiles(mol_no_H, kekuleSmiles=True, canonical=True, isomericSmiles=False, allHsExplicit=False)
            selfies = sf.encoder(smiles_no_stereo)
        except Exception as e:
            print(f"SMILES -> SELFIES conversion failed for {i} molecule\nSMILES: {smiles}\n{e}") # i <-> l
            try:
                smiles_no_stereo = clean_problematic_smiles(smiles_no_stereo)
                selfies = sf.encoder(smiles_no_stereo)
            except Exception as e:
                print(f"SMILES -> SELFIES conversion still failed after cleaning for {i} molecule\n{e}") # i <-> l
                continue
        
        # Check duplicates
        if smiles in isomers:
            # print(f"{l} is duplicate molecule of a molecule with id {isomers[smiles]} skipped")
            # all_atoms.append(None)
            # all_coords.append(None)
            # all_smiles.append(None)
            # continue
            isomers[smiles].append(l)
        else:
            isomers[smiles] = [l]
            
        # Keep data
        all_atoms.append(atoms)
        all_rings.extend(rings)
        all_ring_counts.append(ring_count)
        all_coords.append(coords)
        all_smiles.append(smiles)
        all_selfies.append(selfies)
        
    return all_atoms, all_rings, all_ring_counts, all_coords, all_smiles, all_selfies, isomers

def is_physically_fragmented(mol, max_dist=3.0):
    """Checks whether some fragments of the molecule are separated"""
    conf = mol.GetConformer()
    positions = np.array([conf.GetAtomPosition(i) for i in range(mol.GetNumAtoms())])
    dist_matrix = np.linalg.norm(positions[:, None, :] - positions[None, :, :], axis=-1)
    
    # Simple check: any atom pair in different components farther than threshold
    # Find connected components based on distance
    from scipy.sparse.csgraph import connected_components
    adjacency = dist_matrix < max_dist  # adjacency matrix
    n_components, labels = connected_components(adjacency)
    return n_components > 1

def clean_problematic_smiles(smiles, remove_h=True):
    """
    Cleans SMILES for SELFIES conversion:
    - Removes non-standard stereochemistry/custom markers:
      [S@TB19], [P@TB2], [S@OH18], [S@SP3], [S@SP3H]
    - Converts [SeH], [SH], etc., to just [Se], [S]
    - Keeps normal stereochemistry like [C@H], [C@@H].
    """
    # 1. Remove custom tags
    pattern_custom = r"\[([A-Za-z]+)@(?:TB|OH|SP)\w*\]"
    smiles = re.sub(pattern_custom, r"\1", smiles)
    
    # 2. Replace [XH] → [X] (keep brackets), for any element X except H
    pattern_XH = r"\[([A-Z][a-z]?)H\]"
    smiles = re.sub(pattern_XH, r"[\1]", smiles)
    
    return smiles

def find_indices(lst, target):
    return [i for i, l in enumerate(lst) if l == target]

def save_everything(output_dir):
    """Saves the data into .h5 files"""
    os.makedirs(output_dir, exist_ok=True)
    output_file = os.path.join(output_dir, f"mol3d_mil{f_id}.h5")
    with h5py.File(output_file, "w") as f:
        print("Saving atom types...")
        atom_dt = h5py.special_dtype(vlen=str)
        atom_dset = f.create_dataset('atoms', (len(all_atoms),), dtype=atom_dt)       
        for i, atoms in enumerate(all_atoms):
            atom_dset[i] = '|'.join(atoms)  # Join with delimiter

        print("Saving coords...")
        coord_dt = h5py.special_dtype(vlen=np.dtype('float32'))
        coord_dset = f.create_dataset('coords', (len(all_coords),), dtype=coord_dt)
        for i, coords in enumerate(all_coords):
            coord_dset[i] = np.array(coords, dtype=np.float32).flatten()
        
        print("Saving SMILES...")
        smiles_dset = f.create_dataset('smiles', (len(all_smiles),), dtype=atom_dt)
        for i in range(len(all_smiles)):
            smiles_dset[i] = all_smiles[i]

        print("Saving SELFIES...")
        selfies_dset = f.create_dataset('selfies', (len(all_selfies),), dtype=atom_dt)
        for i in range(len(all_selfies)):
            selfies_dset[i] = all_selfies[i]
            
        print("Saving isomers...")
        f.attrs["isomers"] = json.dumps(isomers)

    output_file = os.path.join(output_dir, f"mol3d_feat_mil{f_id}.h5")
    with h5py.File(output_file, "w") as f:
        print("Saving rings...")
        # Variable-length int dataset for rings
        ring_dt = h5py.special_dtype(vlen=np.dtype('int32'))
        ring_dset = f.create_dataset("rings", (len(all_rings),), dtype=ring_dt)
        for i, ring in enumerate(all_rings):
            ring_dset[i] = np.array(ring, dtype=np.int32)
        # Dataset for number of rings per molecule
        f.create_dataset("nrings", data=np.array(ring_counts, dtype=np.int32))

# %%
files = [r"D:\molecule3d\data\data\raw\combined_mols_0_to_1000000.sdf",
         r"D:\molecule3d\data\data\raw\combined_mols_1000000_to_2000000.sdf",
         r"D:\molecule3d\data\data\raw\combined_mols_2000000_to_3000000.sdf",
         r"D:\molecule3d\data\data\raw\combined_mols_3000000_to_3899647.sdf"]

# %%
########## SELFIES upgrades ##########
default_constraints = sf.get_semantic_constraints()
custom_constraints = {
    # Original constraints (keeping existing working ones)
    'H': 1, 'F': 1, 'Cl': 1, 'Br': 1, 'I': 1,
    'B': 3, 'B+1': 2, 'B-1': 4,
    'O': 2, 'O+1': 3, 'O-1': 1,
    'N': 3, 'N+1': 4, 'N-1': 2,
    'C': 4, 'C+1': 5, 'C-1': 3,
    'P': 5, 'P+1': 6, 'P-1': 4,
    'S': 6, 'S+1': 7, 'S-1': 5,
    '?': 8,
    
    # Group 1 - Alkali metals (neutral forms for organometallic compounds)
    'Li': 1,  # For organolithium compounds
    'Na': 1,  # For organosodium compounds  
    'K': 1,   # For organopotassium compounds
    
    # Group 2 - Alkaline earth metals (neutral and +1 for organo compounds)
    'Be': 2,     # Beryllium in organometallic complexes
    'Be+1': 3,   # Be+ can form 3 bonds in some complexes
    'Mg': 2,     # Grignard reagents, etc.
    'Ca': 2,     # Organocalcium compounds
    
    # Group 13 - Boron group
    'Al': 3,     # Organoaluminum compounds
    'Ga': 3,     # Organogallium compounds
    
    # Group 14 - Carbon group
    'Si': 4, 'Si-4': 4,  # Silanes, silicides
    'Ge': 4, 'Ge+2': 2,  # Germanes, Ge(II) compounds
    
    # Group 15 - Nitrogen group
    'As': 3, 'As+3': 6, 'As+5': 6, 'As-3': 3,  # Arsines, arsenates, arsenides
    
    # Group 16 - Oxygen group
    'Se': 6, 'Se+1': 7, 'Se-1': 5 , 'Se+4': 4, 'Se+6': 6, 'Se-2': 2,  # Selenides, selenates
    
    # Transition metals
    # Scandium
    'Sc': 3,     # Organoscandium compounds
    
    # Titanium
    'Ti': 4, 'Ti+2': 6, 'Ti+3': 6,  # Ti(II), Ti(III), Ti(IV) organometallics
    
    # Vanadium  
    'V': 5, 'V+2': 6, 'V+3': 6, 'V+4': 6,  # Various V oxidation states in complexes
    
    # Chromium
    'Cr': 6, 'Cr+2': 6, 'Cr+3': 6,  # Cr(II), Cr(III), Cr(VI) compounds
    
    # Manganese
    'Mn': 7, 'Mn+2': 6, 'Mn+3': 6, 'Mn+4': 6,  # Various Mn oxidation states
    
    # Iron
    'Fe': 6, 'Fe+2': 6, 'Fe+3': 6,  # Fe(II), Fe(III) organometallics
    
    # Cobalt
    'Co': 6, 'Co+2': 6, 'Co+3': 6,  # Co(II), Co(III) complexes
    
    # Nickel
    'Ni': 4, 'Ni+2': 6,  # Ni(0), Ni(II) organometallics
    
    # Copper
    'Cu': 4, 'Cu+1': 4, 'Cu+2': 6,  # Cu(I), Cu(II) organometallics
    
    # Zinc
    'Zn': 4, 'Zn+2':6,  # Organozinc, Zn(II) complexes
}
default_constraints.update(custom_constraints)
sf.set_semantic_constraints(default_constraints)
print(f"Current SELFIES constraints:\n {sf.get_semantic_constraints()}")

default_alphabet = sf.get_semantic_robust_alphabet()
# extend with new elements from periodic table
custom_alphabet = {
    # Single bonds - neutral atoms
    '[Li]', '[Be]', '[Na]', '[Mg]', '[Al]', '[Si]', '[K]', '[Ca]',
    '[Sc]', '[Ti]', '[V]', '[Cr]', '[Mn]', '[Fe]', '[Co]', '[Ni]',
    '[Cu]', '[Zn]', '[Ga]', '[Ge]', '[As]', '[Se]',
    
    # Single bonds - charged species that form covalent bonds
    '[Be+1]', '[Si-4]', '[Ge+2]', '[As+3]', '[As+5]', '[As-3]',
    '[Se+4]', '[Se+6]', '[Se-2]',
    
    # Single bonds - transition metal oxidation states
    '[Ti+2]', '[Ti+3]', '[V+2]', '[V+3]', '[V+4]',
    '[Cr+2]', '[Cr+3]', '[Mn+2]', '[Mn+3]', '[Mn+4]',
    '[Fe+2]', '[Fe+3]', '[Co+2]', '[Co+3]', '[Ni+2]', 
    '[Cu+1]', '[Cu+2]', '[Zn+2]',
    
    # Double bonds (=) - elements that can form double bonds
    '[=Si]', '[=Ge]', '[=As]', '[=Se]',
    '[=Ti]', '[=V]', '[=Cr]', '[=Mn]', '[=Fe]', '[=Co]', '[=Ni]',
}
for atom in custom_alphabet:
    default_alphabet.add(f"[{custom_alphabet}]")
print(f"Current SELFIES alphabet:\n {sf.get_semantic_robust_alphabet()}")
# Out:
# Current SELFIES constraints:
#  {'H': 1, 'F': 1, 'Cl': 1, 'Br': 1, 'I': 1, 'B': 3, 'B+1': 2, 'B-1': 4, 'O': 2, 'O+1': 3, 'O-1': 1, 'N': 3, 'N+1': 4, 'N-1': 2, 'C': 4, 'C+1': 5, 'C-1': 3, 'P': 5, 'P+1': 6, 'P-1': 4, 'S': 6, 'S+1': 7, 'S-1': 5, '?': 8, 'Li': 1, 'Na': 1, 'K': 1, 'Be': 2, 'Be+1': 3, 'Mg': 2, 'Ca': 2, 'Al': 3, 'Ga': 3, 'Si': 4, 'Si-4': 4, 'Ge': 4, 'Ge+2': 2, 'As': 3, 'As+3': 6, 'As+5': 6, 'As-3': 3, 'Se': 6, 'Se+1': 7, 'Se-1': 5, 'Se+4': 4, 'Se+6': 6, 'Se-2': 2, 'Sc': 3, 'Ti': 4, 'Ti+2': 6, 'Ti+3': 6, 'V': 5, 'V+2': 6, 'V+3': 6, 'V+4': 6, 'Cr': 6, 'Cr+2': 6, 'Cr+3': 6, 'Mn': 7, 'Mn+2': 6, 'Mn+3': 6, 'Mn+4': 6, 'Fe': 6, 'Fe+2': 6, 'Fe+3': 6, 'Co': 6, 'Co+2': 6, 'Co+3': 6, 'Ni': 4, 'Ni+2': 6, 'Cu': 4, 'Cu+1': 4, 'Cu+2': 6, 'Zn': 4, 'Zn+2': 6}
# Current SELFIES alphabet:
#  {'[Mn+3]', '[=Fe+2]', '[#Ti+2]', '[#Se-1]', '[Cr]', '[=B]', '[#S-1]', '[#V+2]', '[Na]', '[Se+1]', '[Si]', '[O+1]', '[#Mn+2]', '[Cu+2]', '[N]', '[Mn]', '[=C+1]', '[=O+1]', '[=V]', '[Se]', '[Br]', '[=Fe+3]', '[P+1]', '[#Mn+3]', '[=Fe]', '[B-1]', '[#Fe+2]', '[F]', '[=P+1]', '[#As]', '[#As-3]', '[Se+6]', '[=Cr+2]', '[Fe+2]', '[#N]', '[=P]', '[V+2]', '[Zn+2]', '[=Ni+2]', '[=Cr+3]', '[#As+5]', '[Se-1]', '[Zn]', '[Ge+2]', '[=P-1]', '[=Ring1]', '[=Co+3]', '[=Mn]', '[#Be+1]', '[#V]', '[Fe]', '[S+1]', '[K]', '[#Mn+4]', '[B+1]', '[Si-4]', '[Ni]', '[#Branch2]', '[=Si]', '[=V+2]', '[Cr+2]', "[{'[Mn+3]', '[Al]', '[Ge]', '[Cr+2]', '[Se-2]', '[Co+3]', '[=As]', '[As+5]', '[Cr]', '[Be]', '[Ti]', '[=Ni]', '[Na]', '[Ga]', '[Se+4]', '[Mn+4]', '[Si]', '[Cu+2]', '[Ca]', '[=Ti]', '[V]', '[Mn]', '[=V]', '[Be+1]', '[Se]', '[Ti+3]', '[Fe+3]', '[Cr+3]', '[V+4]', '[Li]', '[=Fe]', '[Cu]', '[Se+6]', '[Fe+2]', '[V+2]', '[Zn+2]', '[=Ge]', '[Cu+1]', '[Zn]', '[Ge+2]', '[As]', '[Mg]', '[As+3]', '[Ti+2]', '[Ni+2]', '[Sc]', '[=Mn]', '[Fe]', '[=Cr]', '[Co]', '[V+3]', '[K]', '[Ni]', '[Si-4]', '[As-3]', '[=Se]', '[Co+2]', '[=Co]', '[Mn+2]', '[=Si]'}]", '[Se-2]', '[=Ti+2]', '[=As]', '[As+5]', '[#P+1]', '[#Ti]', '[=B-1]', '[#Si]', '[#N+1]', '[#Cu+1]', '[P-1]', '[=Ring2]', '[=Cu+1]', '[Fe+3]', '[=Se+6]', '[=Ti+3]', '[=Branch2]', '[Branch2]', '[#Co+3]', '[Branch3]', '[=B+1]', '[=As+5]', '[#Se+1]', '[=Ge+2]', '[#Zn]', '[=Ring3]', '[#Zn+2]', '[#P]', '[Ti+2]', '[=V+4]', '[Branch1]', '[Sc]', '[O-1]', '[#B]', '[#Cu+2]', '[#Branch1]', '[=Cr]', '[#Mn]', '[Cl]', '[#C+1]', '[Co+2]', '[=Be+1]', '[H]', '[Ti+3]', '[#V+4]', '[=Cu+2]', '[Al]', '[Ge]', '[#P-1]', '[#C-1]', '[#Fe]', '[#Se+6]', '[Ti]', '[=Branch1]', '[=Ni]', '[Se+4]', '[Mn+4]', '[#Co]', '[Ring3]', '[=Branch3]', '[I]', '[Ca]', '[=Ti]', '[=N]', '[V]', '[=Co+2]', '[N+1]', '[#Cr+2]', '[=O]', '[#Co+2]', '[#C]', '[#Ga]', '[V+4]', '[=V+3]', '[Cr+3]', '[O]', '[=Se-1]', '[Cu]', '[#Si-4]', '[=S-1]', '[=Mn+2]', '[#V+3]', '[#B-1]', '[#Ge]', '[P]', '[S-1]', '[=Mg]', '[=Ga]', '[Cu+1]', '[#Ni+2]', '[#S+1]', '[Mg]', '[=Si-4]', '[As]', '[=Al]', '[#Sc]', '[Ni+2]', '[=Sc]', '[C-1]', '[N-1]', '[#Cr]', '[=N-1]', '[=C-1]', '[=S]', '[B]', '[#Branch3]', '[=S+1]', '[=C]', '[Co+3]', '[Be]', '[=Mn+4]', '[=Se+4]', '[Ga]', '[C]', '[=Mn+3]', '[Be+1]', '[#S]', '[Ring2]', '[#O+1]', '[=Zn+2]', '[S]', '[Li]', '[#Fe+3]', '[C+1]', '[#As+3]', '[=Zn]', '[#Cr+3]', '[#Se+4]', '[=Ge]', '[=Cu]', '[=Ca]', '[=As-3]', '[#Ni]', '[#Se]', '[Ring1]', '[As+3]', '[#Al]', '[=Se+1]', '[=Be]', '[#Ti+3]', '[=Se-2]', '[Co]', '[V+3]', '[As-3]', '[=Se]', '[#Cu]', '[=Co]', '[=N+1]', '[Mn+2]', '[=As+3]'}

# %%
for f_id in [1, 2, 3, 4]:
    all_atoms, all_rings, ring_counts, all_coords, all_smiles, all_selfies, isomers = process_data(files[f_id-1])
    save_everything(r"D:\molecule3d\data\processed")
# Out:
# [17:59:55] Explicit valence for atom # 1 P, 6, is greater than permitted
# [17:59:55] ERROR: Could not sanitize molecule ending on line 507406
# [17:59:55] ERROR: Explicit valence for atom # 1 P, 6, is greater than permitted
# [17:59:56] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 5
# [17:59:56] Explicit valence for atom # 0 Al, 4, is greater than permitted
# [17:59:56] ERROR: Could not sanitize molecule ending on line 553299
# [17:59:56] ERROR: Explicit valence for atom # 0 Al, 4, is greater than permitted
# [18:00:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:00:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 0 1
# [18:00:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 0
# [18:00:09] Explicit valence for atom # 6 Si, 6, is greater than permitted
# [18:00:09] ERROR: Could not sanitize molecule ending on line 1209872
# [18:00:09] ERROR: Explicit valence for atom # 6 Si, 6, is greater than permitted
# [18:00:21] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 8
# [18:00:21] The 2 defining bonds for an atropisomer are co-planar - atoms are: 8 9
# [18:00:24] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:00:30] Explicit valence for atom # 9 Si, 6, is greater than permitted
# [18:00:30] ERROR: Could not sanitize molecule ending on line 2027375
# [18:00:30] ERROR: Explicit valence for atom # 9 Si, 6, is greater than permitted
# [18:00:38] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 3
# [18:00:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 2
# [18:00:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 1
# [18:00:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:00:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 3
# [18:00:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:00:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:00:49] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 2
# [18:00:49] Warning: molecule is tagged as 3D, but all Z coords are zero and 2D stereo markers have been found, marking the mol as 2D.
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 2
# [18:00:49] The 2 defining bonds for an atropisomer are co-planar - atoms are: 0 2
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 3
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 2
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 1
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 3
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 2
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 1
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 0
# [18:00:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:00:50] Both bonds on one end of an atropisomer are on the same side - atoms are: 8 6
# [18:00:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 7
# [18:00:51] The 2 defining bonds for an atropisomer are co-planar - atoms are: 1 2
# [18:00:52] The 2 defining bonds for an atropisomer are co-planar - atoms are: 10 9
# [18:00:52] The 2 defining bonds for an atropisomer are co-planar - atoms are: 11 10
# [18:00:53] Explicit valence for atom # 10 Si, 5, is greater than permitted
# [18:00:53] ERROR: Could not sanitize molecule ending on line 3223257
# [18:00:53] ERROR: Explicit valence for atom # 10 Si, 5, is greater than permitted
# [18:00:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 8 7
# [18:00:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 5
# [18:00:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 8 7
# [18:00:56] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 20
# [18:00:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 14 13
# [18:00:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 11 12
# [18:00:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 15 16
# [18:01:17] Unexpected error hit on line 4236371
# [18:01:17] ERROR: moving to the beginning of the next molecule
# [18:01:31] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 7
# [18:01:58] Warning: molecule is tagged as 3D, but all Z coords are zero and 2D stereo markers have been found, marking the mol as 2D.
# [18:02:08] The 2 defining bonds for an atropisomer are co-planar - atoms are: 1 2
# [18:02:09] Explicit valence for atom # 1 Si, 5, is greater than permitted
# [18:02:09] ERROR: Could not sanitize molecule ending on line 6437834
# [18:02:09] ERROR: Explicit valence for atom # 1 Si, 5, is greater than permitted
# [18:02:18] Both bonds on one end of an atropisomer are on the same side - atoms are: 14 16
# [18:02:19] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 2
# [18:02:19] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 2
# [18:02:22] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 5
# [18:02:22] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 5
# [18:02:22] The 2 defining bonds for an atropisomer are co-planar - atoms are: 7 6
# [18:02:25] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 3
# [18:02:25] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 3
# [18:02:25] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 2
# [18:02:25] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 2
# [18:02:27] The 2 defining bonds for an atropisomer are co-planar - atoms are: 1 2
# [18:02:31] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 4
# [18:02:32] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 3
# [18:02:33] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 8
# [18:02:34] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 3
# [18:02:34] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 5
# [18:02:34] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 6
# [18:02:34] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 5
# [18:02:35] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 3
# [18:02:39] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 4
# [18:02:46] The 2 defining bonds for an atropisomer are co-planar - atoms are: 11 9
# [18:02:46] Warning: molecule is tagged as 3D, but all Z coords are zero and 2D stereo markers have been found, marking the mol as 2D.
# [18:02:49] The 2 defining bonds for an atropisomer are co-planar - atoms are: 7 6
# [18:03:02] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 5
# [18:03:03] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 4
# [18:03:03] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 5
# [18:03:03] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 2
# [18:03:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 4
# [18:03:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:03:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:03:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:03:23] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 7
# [18:03:31] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 3
# [18:03:31] The 2 defining bonds for an atropisomer are co-planar - atoms are: 1 0
# [18:03:32] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 6
# [18:03:40] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 9
# [18:03:41] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 7
# [18:03:43] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 2
# [18:03:47] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 12
# [18:03:48] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 2
# [18:03:50] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 12
# [18:03:57] The 2 defining bonds for an atropisomer are co-planar - atoms are: 10 11
# [18:03:58] Explicit valence for atom # 6 Si, 5, is greater than permitted
# [18:03:58] ERROR: Could not sanitize molecule ending on line 12100425
# [18:03:58] ERROR: Explicit valence for atom # 6 Si, 5, is greater than permitted
# [18:03:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 13 11
# [18:03:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:03:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:03:59] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 8
# [18:04:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 7
# [18:04:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 7
# [18:04:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:04:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:04:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:04:06] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:04:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:04:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:04:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 8 9
# [18:04:08] The 2 defining bonds for an atropisomer are co-planar - atoms are: 11 7
# [18:04:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:09] The 2 defining bonds for an atropisomer are co-planar - atoms are: 7 11
# [18:04:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:04:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:04:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:04:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:04:22] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:28] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 12
# [18:04:29] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:04:30] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:30] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:04:30] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:04:31] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:33] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:04:34] The 2 defining bonds for an atropisomer are co-planar - atoms are: 8 12
# [18:04:34] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:04:35] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 13
# [18:04:36] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:37] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:37] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:40] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:40] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:04:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 6
# [18:04:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:04:44] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:04:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 8
# [18:04:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:04:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:04:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 6
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:04:46] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:04:46] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:04:46] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 6
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:04:46] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 1
# [18:04:46] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 7
# [18:04:47] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:04:47] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:04:47] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 1
# [18:04:47] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:04:47] The 2 defining bonds for an atropisomer are co-planar - atoms are: 7 0
# [18:04:48] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 12
# [18:04:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 8
# [18:04:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:04:53] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 7
# [18:04:53] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 0
# [18:04:53] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:04:54] The 2 defining bonds for an atropisomer are co-planar - atoms are: 13 9
# [18:04:54] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:04:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 1
# [18:04:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:04:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:04:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:04:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:04:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:05:07] Explicit valence for atom # 5 Si, 5, is greater than permitted
# [18:05:07] ERROR: Could not sanitize molecule ending on line 15561574
# [18:05:07] ERROR: Explicit valence for atom # 5 Si, 5, is greater than permitted
# [18:05:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 12
# [18:05:17] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:05:17] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:05:21] The 2 defining bonds for an atropisomer are co-planar - atoms are: 11 7
# [18:05:28] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 5
# [18:05:32] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:05:41] Both bonds on one end of an atropisomer are on the same side - atoms are: 8 10
# [18:05:57] Explicit valence for atom # 8 Si, 5, is greater than permitted
# [18:05:57] ERROR: Could not sanitize molecule ending on line 18098692
# [18:05:57] ERROR: Explicit valence for atom # 8 Si, 5, is greater than permitted
# [18:06:02] Warning: molecule is tagged as 3D, but all Z coords are zero and 2D stereo markers have been found, marking the mol as 2D.
# [18:06:09] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 9
# [18:06:13] Explicit valence for atom # 12 Si, 5, is greater than permitted
# [18:06:13] ERROR: Could not sanitize molecule ending on line 18921399
# [18:06:13] ERROR: Explicit valence for atom # 12 Si, 5, is greater than permitted
# [18:06:23] The 2 defining bonds for an atropisomer are co-planar - atoms are: 11 7
# [18:06:25] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 8
# [18:06:26] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 12
# [18:06:43] The 2 defining bonds for an atropisomer are co-planar - atoms are: 7 6
# [18:06:43] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 3
# [18:06:43] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 13
# [18:06:43] Both bonds on one end of an atropisomer are on the same side - atoms are: 12 6
# [18:06:43] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 2
# [18:06:44] Explicit valence for atom # 9 Si, 5, is greater than permitted
# [18:06:44] ERROR: Could not sanitize molecule ending on line 20528789
# [18:06:44] ERROR: Explicit valence for atom # 9 Si, 5, is greater than permitted
# [18:06:44] Explicit valence for atom # 10 Si, 5, is greater than permitted
# [18:06:44] ERROR: Could not sanitize molecule ending on line 20529931
# [18:06:44] ERROR: Explicit valence for atom # 10 Si, 5, is greater than permitted
# [18:06:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 12 5
# [18:06:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 13 12
# [18:06:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:06:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:46] Explicit valence for atom # 8 Si, 5, is greater than permitted
# [18:06:46] ERROR: Could not sanitize molecule ending on line 20641589
# [18:06:46] ERROR: Explicit valence for atom # 8 Si, 5, is greater than permitted
# [18:06:49] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 10
# [18:06:50] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:06:50] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:06:50] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:50] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:51] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:52] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:06:53] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 8
# [18:06:54] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:54] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:54] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 0
# [18:06:54] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 8
# [18:06:54] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:54] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:06:56] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 8
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:06:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:06:58] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:06:59] The 2 defining bonds for an atropisomer are co-planar - atoms are: 0 6
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 12
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:06:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 0
# [18:07:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:01] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:01] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:01] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:01] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:01] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 0
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:07:03] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 1
# [18:07:03] The 2 defining bonds for an atropisomer are co-planar - atoms are: 0 4
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:07:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:04] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 10
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 15 10
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 9 6
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:04] The 2 defining bonds for an atropisomer are co-planar - atoms are: 0 14
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:07:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:07:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:07:06] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:06] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 6
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 1
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 1
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 0
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:07:08] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 5
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 2
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 7
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 0
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 1
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 7
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:07:10] The 2 defining bonds for an atropisomer are co-planar - atoms are: 1 2
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [18:07:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 1
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 5
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:07:14] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [18:07:14] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:07:15] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:15] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:15] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 10
# [18:07:15] Both bonds on one end of an atropisomer are on the same side - atoms are: 15 8
# [18:07:15] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 5
# [18:07:15] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 4
# [18:07:15] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 2
# [18:07:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 13 12
# [18:07:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 0
# [18:07:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [18:07:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [18:07:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 11 15
# [18:07:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [18:07:16] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [18:07:17] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [18:07:17] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# ...
# [22:39:52] The 2 defining bonds for an atropisomer are co-planar - atoms are: 7 4
# [22:39:52] The 2 defining bonds for an atropisomer are co-planar - atoms are: 7 5
# [22:39:53] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 8
# [22:39:54] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 0
# [22:39:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 13 14
# [22:39:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 15 14
# [22:39:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 12 15
# [22:39:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 5
# [22:39:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 11 9
# [22:39:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 11 10
# [22:40:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [22:40:01] Both bonds on one end of an atropisomer are on the same side - atoms are: 8 3
# [22:40:01] The 2 defining bonds for an atropisomer are co-planar - atoms are: 7 8
# [22:40:01] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 3
# [22:40:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 4
# [22:40:02] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [22:40:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:40:03] Both bonds on one end of an atropisomer are on the same side - atoms are: 13 15
# [22:40:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 6
# [22:40:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 0
# [22:40:06] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 8
# [22:40:06] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 4
# [22:40:06] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:40:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 4
# [22:40:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:40:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 3
# [22:40:09] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 6
# [22:40:09] Both bonds on one end of an atropisomer are on the same side - atoms are: 13 6
# [22:40:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 11 12
# [22:40:12] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 12
# [22:40:13] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 5
# [22:40:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 2
# [22:40:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 3
# [22:40:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 6
# [22:40:17] Both bonds on one end of an atropisomer are on the same side - atoms are: 8 10
# [22:40:17] Both bonds on one end of an atropisomer are on the same side - atoms are: 8 0
# [22:40:17] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 1
# [22:40:17] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 7
# [22:40:18] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:40:20] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 13
# [22:40:27] Explicit valence for atom # 7 Si, 5, is greater than permitted
# [22:40:27] ERROR: Could not sanitize molecule ending on line 46891361
# [22:40:27] ERROR: Explicit valence for atom # 7 Si, 5, is greater than permitted
# [22:40:31] Both bonds on one end of an atropisomer are on the same side - atoms are: 12 9
# [22:40:32] The 2 defining bonds for an atropisomer are co-planar - atoms are: 13 7
# [22:40:36] The 2 defining bonds for an atropisomer are co-planar - atoms are: 12 13
# [22:40:36] The 2 defining bonds for an atropisomer are co-planar - atoms are: 11 12
# [22:40:47] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:40:50] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 0
# [22:40:50] Warning: molecule is tagged as 3D, but all Z coords are zero and 2D stereo markers have been found, marking the mol as 2D.
# [22:40:51] The 2 defining bonds for an atropisomer are co-planar - atoms are: 11 10
# [22:40:53] The 2 defining bonds for an atropisomer are co-planar - atoms are: 0 2
# [22:40:53] The 2 defining bonds for an atropisomer are co-planar - atoms are: 1 2
# [22:40:54] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [22:40:55] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 2
# [22:40:57] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 8
# [22:40:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 3
# [22:40:57] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:40:57] The 2 defining bonds for an atropisomer are co-planar - atoms are: 1 0
# [22:40:58] Warning: molecule is tagged as 3D, but all Z coords are zero and 2D stereo markers have been found, marking the mol as 2D.
# [22:40:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 8
# [22:40:58] The 2 defining bonds for an atropisomer are co-planar - atoms are: 10 7
# [22:40:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 10
# [22:40:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 11
# [22:40:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 5
# [22:40:58] Both bonds on one end of an atropisomer are on the same side - atoms are: 14 11
# [22:40:59] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 11
# [22:41:00] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 12
# [22:41:01] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 4
# [22:41:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 6
# [22:41:06] Explicit valence for atom # 3 Si, 5, is greater than permitted
# [22:41:06] ERROR: Could not sanitize molecule ending on line 49422668
# [22:41:06] ERROR: Explicit valence for atom # 3 Si, 5, is greater than permitted
# [22:41:06] Explicit valence for atom # 14 Si, 5, is greater than permitted
# [22:41:06] ERROR: Could not sanitize molecule ending on line 49422741
# [22:41:06] ERROR: Explicit valence for atom # 14 Si, 5, is greater than permitted
# [22:41:06] Explicit valence for atom # 5 Si, 5, is greater than permitted
# [22:41:06] ERROR: Could not sanitize molecule ending on line 49422877
# [22:41:06] ERROR: Explicit valence for atom # 5 Si, 5, is greater than permitted
# [22:41:06] Explicit valence for atom # 4 Si, 5, is greater than permitted
# [22:41:06] ERROR: Could not sanitize molecule ending on line 49422908
# [22:41:06] ERROR: Explicit valence for atom # 4 Si, 5, is greater than permitted
# [22:41:06] Explicit valence for atom # 3 Si, 5, is greater than permitted
# [22:41:06] ERROR: Could not sanitize molecule ending on line 49422939
# [22:41:06] ERROR: Explicit valence for atom # 3 Si, 5, is greater than permitted
# [22:41:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 0
# [22:41:11] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 4
# [22:41:11] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 0
# [22:41:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 2
# SMILES -> SELFIES conversion failed for 742996 molecule
# SMILES: C1=CC=[AsH2]C=C1
# input violates the currently-set semantic constraints
# 	SMILES: C1=CC=[AsH2]C=C1
# 	Errors:
# 	[[AsH2] with 3 bond(s) - a max. of 1 bond(s) was specified]
#
# SMILES -> SELFIES conversion still failed after cleaning for 742996 molecule
# input violates the currently-set semantic constraints
# 	SMILES: C1=CC=[AsH2]C=C1
# 	Errors:
# 	[[AsH2] with 3 bond(s) - a max. of 1 bond(s) was specified]
# [22:41:18] Explicit valence for atom # 2 Si, 5, is greater than permitted
# [22:41:18] ERROR: Could not sanitize molecule ending on line 50210173
# [22:41:18] ERROR: Explicit valence for atom # 2 Si, 5, is greater than permitted
# [22:41:18] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 5
# [22:41:18] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 4
# [22:41:18] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 6
# [22:41:18] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:41:19] The 2 defining bonds for an atropisomer are co-planar - atoms are: 0 10
# [22:41:19] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:41:20] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [22:41:20] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:41:20] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 4
# [22:41:20] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 1
# [22:41:21] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [22:41:22] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [22:41:23] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [22:41:28] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [22:41:29] Both bonds on one end of an atropisomer are on the same side - atoms are: 11 7
# [22:41:29] The 2 defining bonds for an atropisomer are co-planar - atoms are: 14 7
# [22:41:34] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 2
# [22:41:34] Both bonds on one end of an atropisomer are on the same side - atoms are: 9 6
# [22:41:34] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 1
# [22:41:34] The 2 defining bonds for an atropisomer are co-planar - atoms are: 2 3
# [22:41:35] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 2
# [22:41:35] The 2 defining bonds for an atropisomer are co-planar - atoms are: 3 4
# [22:41:35] Both bonds on one end of an atropisomer are on the same side - atoms are: 3 1
# [22:41:36] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 0
# [22:41:56] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 10
# [22:41:57] The 2 defining bonds for an atropisomer are co-planar - atoms are: 16 8
# [22:41:58] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 10
# [22:41:59] The 2 defining bonds for an atropisomer are co-planar - atoms are: 14 7
# [22:42:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 10
# [22:42:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 11
# [22:42:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 11
# [22:42:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 12 8
# [22:42:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 10 15
# [22:42:00] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 16
# [22:42:02] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 11
# [22:42:03] Unexpected error hit on line 53128557
# [22:42:03] ERROR: moving to the beginning of the next molecule
# [22:42:03] The 2 defining bonds for an atropisomer are co-planar - atoms are: 11 5
# [22:42:03] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 10
# [22:42:04] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 13
# [22:42:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:42:04] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [22:42:04] The 2 defining bonds for an atropisomer are co-planar - atoms are: 1 2
# [22:42:04] The 2 defining bonds for an atropisomer are co-planar - atoms are: 5 12
# [22:42:05] The 2 defining bonds for an atropisomer are co-planar - atoms are: 4 9
# [22:42:05] The 2 defining bonds for an atropisomer are co-planar - atoms are: 9 4
# [22:42:06] The 2 defining bonds for an atropisomer are co-planar - atoms are: 8 4
# [22:42:06] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 11
# [22:42:06] The 2 defining bonds for an atropisomer are co-planar - atoms are: 10 7
# [22:42:07] The 2 defining bonds for an atropisomer are co-planar - atoms are: 12 8
# [22:42:07] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 5
# [22:42:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 7 3
# [22:42:09] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 10
# [22:42:11] The 2 defining bonds for an atropisomer are co-planar - atoms are: 15 11
# [22:42:13] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 8
# [22:42:28] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 5
# [22:42:45] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# [22:42:45] Explicit valence for atom # 12 Si, 5, is greater than permitted
# [22:42:45] ERROR: Could not sanitize molecule ending on line 55924610
# [22:42:45] ERROR: Explicit valence for atom # 12 Si, 5, is greater than permitted
# [22:42:48] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 7
# [22:42:48] Both bonds on one end of an atropisomer are on the same side - atoms are: 2 9
# [22:42:50] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 5
# [22:42:50] Explicit valence for atom # 5 Si, 5, is greater than permitted
# [22:42:50] ERROR: Could not sanitize molecule ending on line 56202775
# [22:42:50] ERROR: Explicit valence for atom # 5 Si, 5, is greater than permitted
# [22:42:53] Unexpected error hit on line 56391017
# [22:42:53] ERROR: moving to the beginning of the next molecule
# [22:42:54] The 2 defining bonds for an atropisomer are co-planar - atoms are: 10 6
# [22:43:05] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 8
# [22:43:08] Both bonds on one end of an atropisomer are on the same side - atoms are: 9 7
# [22:43:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 5
# [22:43:10] The 2 defining bonds for an atropisomer are co-planar - atoms are: 10 9
# [22:43:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 9 5
# [22:43:10] The 2 defining bonds for an atropisomer are co-planar - atoms are: 10 9
# [22:43:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 9 5
# [22:43:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 10 5
# [22:43:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 1 3
# [22:43:10] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 2
# [22:43:10] The 2 defining bonds for an atropisomer are co-planar - atoms are: 0 9
# [22:43:10] The 2 defining bonds for an atropisomer are co-planar - atoms are: 14 9
# [22:43:13] Explicit valence for atom # 14 Si, 5, is greater than permitted
# [22:43:13] ERROR: Could not sanitize molecule ending on line 57701741
# [22:43:13] ERROR: Explicit valence for atom # 14 Si, 5, is greater than permitted
# [22:43:15] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 10
# [22:43:30] Both bonds on one end of an atropisomer are on the same side - atoms are: 5 3
# [22:43:38] Both bonds on one end of an atropisomer are on the same side - atoms are: 6 2
# [22:43:41] The 2 defining bonds for an atropisomer are co-planar - atoms are: 6 5
# [22:43:41] Both bonds on one end of an atropisomer are on the same side - atoms are: 4 8
# [22:43:44] Both bonds on one end of an atropisomer are on the same side - atoms are: 0 1
# Saving atom types...
# Saving coords...
# Saving rings...
# Saving SMILES...
# Saving SELFIES...
# Saving isomers...
